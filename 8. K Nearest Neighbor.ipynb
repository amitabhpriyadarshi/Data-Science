# %% [markdown]
# <b>What is KNN Algorithm?</b><br>
# "K Nearest Neighbour is a simple algorithm that stores all the available cases and classifies the new data or case based on a similarity measure."<br>
# It suggests that if you are similar to your neighbor then you are one of them.<br>
# Example: if apple is closest to banana kiwi and pine apple rather than monkey snake and bull. then apple belongs to fruits.<br>
# KNN is used when you want to predict similar items. eg: predict suggestions of movie or shopping item etc.<br>
#
# <b>Industrial Use case of KNN Algorithm</b><br>
# Recommender System<br>
# Concept Search<br>
# Handwritting detection, image recognisation, Video recognisation <br>
#
# <b>How things are predicted using KNN Algorithm</b><br>
#
# ![Screenshot%202023-01-23%20at%2011.27.55%20AM.png](attachment:Screenshot%202023-01-23%20at%2011.27.55%20AM.png)
# <b>How to choose the value of K?</b><br>
# K in KNN is the number of nearest neighbor that you want to seclect to see the similarity.<br>
#
# <b>1. Implementation of KNN Algorithm from scratch</b><br>

# %% [markdown]
# ![Screenshot%202023-01-23%20at%2011.30.06%20AM.png](attachment:Screenshot%202023-01-23%20at%2011.30.06%20AM.png)
#
# <pre>
# Steps 1:<b>Handle Data</b> : Open the dataset from csv and split into test/train dataset
# Steps 2:<b>Similarity</b> : Calculate the distance between two data instances
# Steps 3:<b>Neighbor</b> : Locate k most similar data instances
# Steps 4:<b>Response</b> : Generate a response from set of data instance
# Steps 5:<b>Accuracy</b> : Summarizing the accuracy of predictions
# Steps 6:<b>Main</b> : Tie it all together
# </pre>
# <b>2. Compare the built model using scikit learn</b><br>

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline

iris = pd.read_csv('./iris.csv')
iris.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
X= iris.iloc[:,:-1].values 
#[:,:-1] = first : takes every row. :-1 select every column expect last one
y= iris.iloc[:,4].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.33, random_state=0)
print(len(X_train))
print(len(X_test))
# Out:
# 100
# 50

# %%
#fitting multiple linear rigression to the training set
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=7)
model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred = model.predict(X_test)
# Out:
# /Users/amitabhpriyadarshi/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
#representing the confusion matrix
from sklearn.metrics import confusion_matrix
cf_matrix = confusion_matrix(y_test, y_pred)
print(cf_matrix)
# Out:
# [[16  0  0]
#  [ 0 18  1]
#  [ 0  0 15]]

# %%
from sklearn.metrics import accuracy_score
score = accuracy_score(y_test, y_pred)
print(score)
# Out:
# 0.98

# %%
r = [[5.3, 3.3, 1.4 , 2.5]]
print(r)
print(model.predict(r))
# Out:
# [[5.3, 3.3, 1.4, 2.5]]
# ['Setosa']
# /Users/amitabhpriyadarshi/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
